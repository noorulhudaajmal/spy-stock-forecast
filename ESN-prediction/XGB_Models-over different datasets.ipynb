# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import warnings
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from functools import reduce
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
import plotly.express as px
import plotly.graph_objects as go
import datetime
from sklearn.model_selection import GridSearchCV

warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
warnings.filterwarnings(action='once')
# Out:
# /home/huda/.local/lib/python3.8/site-packages/xarray/backends/cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %% [markdown]
# # Data Setup

# %%
#ETL-> extract, Transform & Load Pipeline 
# This function will read the input dataframe and perform some necessary functions:
# 1. Dropping rows with null values
# 2. Converting dates/times column to date_time format under column name "Date"
# 3. Remove the percentage symbols from the values of column(like Change% etc.) to make if float[for calculations]

def etl(df):
    for i in df.columns: # iterating over columns of input dataframe
        if df[i].isna().sum() == df.shape[0]: #if all the values of certain column in null, drop that
            df.drop(i,axis=1,inplace=True)
            continue
        if i=="Time": # if column with name "Time" is found, convert its values to date_time format
            df["Date"] = pd.to_datetime(df[i])
            df.drop("Time",axis=1,inplace=True)
        elif i=="Date": # if column with name "Date" is found, convert its values to date_time format
            df[i] = pd.to_datetime(df[i])
        elif df[i].dtype == "object": # if some column is found with datatype other than float/int etc.
            #convert its values to str
            df[i] = df[i].astype(str)
            df[i] = df[i].apply(lambda x:re.sub('[%]',"",x))
            df[i] = df[i].astype(float)
    return df

# %%
# data with 68 features

# %%
data = etl(pd.read_csv("df_all_predictors.csv"))

# %%
data.head(2)
# Out:
#         Date  SPY Open  SPY High  SPY Low  SPY Last  SPY Change  SPY %Chg  \
# 0 2018-10-03    292.74    293.21   291.32    291.72        0.16      0.05
# 1 2018-10-04    291.18    291.24   287.66    289.44       -2.28     -0.78
#
#     SPY Volume    SPY RSI  SPY_o Imp Vol  ...  DXY Change  DXY %Chg  \
# 0   64694500.0  54.634025           8.69  ...        0.59      0.62
# 1  111545904.0  54.634025          10.07  ...       -0.32     -0.33
#
#    DXY Volume  CMBO Open  CMBO High  CMBO Low  CMBO Last  CMBO Change  \
# 0         0.0    1980.64    1980.64   1980.64    1980.64         1.37
# 1         0.0    1967.24    1967.24   1967.24    1967.24       -13.40
#
#    CMBO %Chg  CMBO Volume
# 0       0.07          0.0
# 1      -0.68          0.0
#
# [2 rows x 68 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097 entries, 0 to 1096
# Data columns (total 68 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1097 non-null   datetime64[ns]
#  1   SPY Open            1097 non-null   float64
#  2   SPY High            1097 non-null   float64
#  3   SPY Low             1097 non-null   float64
#  4   SPY Last            1097 non-null   float64
#  5   SPY Change          1097 non-null   float64
#  6   SPY %Chg            1097 non-null   float64
#  7   SPY Volume          1097 non-null   float64
#  8   SPY RSI             1097 non-null   float64
#  9   SPY_o Imp Vol       1097 non-null   float64
#  10  SPY_o 1D IV Chg     1097 non-null   float64
#  11  SPY_o IV Rank       1097 non-null   float64
#  12  SPY_o IV Pctl       1097 non-null   float64
#  13  SPY_o Put/Call Vol  1097 non-null   float64
#  14  SPY_o Options Vol   1097 non-null   float64
#  15  SPY_o Put/Call OI   1097 non-null   float64
#  16  SPY_o Total OI      1097 non-null   float64
#  17  TLT Open            1097 non-null   float64
#  18  TLT High            1097 non-null   float64
#  19  TLT Low             1097 non-null   float64
#  20  TLT Last            1097 non-null   float64
#  21  TLT Change          1097 non-null   float64
#  22  TLT %Chg            1097 non-null   float64
#  23  TLT Volume          1097 non-null   float64
#  24  TLT_o Imp Vol       1097 non-null   float64
#  25  TLT_o 1D IV Chg     1097 non-null   float64
#  26  TLT_o IV Rank       1097 non-null   float64
#  27  TLT_o IV Pctl       1097 non-null   float64
#  28  TLT_o Put/Call Vol  1097 non-null   float64
#  29  TLT_o Options Vol   1097 non-null   float64
#  30  TLT_o Put/Call OI   1097 non-null   float64
#  31  TLT_o Total OI      1097 non-null   float64
#  32  GLD Open            1097 non-null   float64
#  33  GLD High            1097 non-null   float64
#  34  GLD Low             1097 non-null   float64
#  35  GLD Last            1097 non-null   float64
#  36  GLD Change          1097 non-null   float64
#  37  GLD %Chg            1097 non-null   float64
#  38  GLD Volume          1097 non-null   float64
#  39  GLD_o Imp Vol       1097 non-null   float64
#  40  GLD_o 1D IV Chg     1097 non-null   float64
#  41  GLD_o IV Rank       1097 non-null   float64
#  42  GLD_o IV Pctl       1097 non-null   float64
#  43  GLD_o Put/Call Vol  1097 non-null   float64
#  44  GLD_o Options Vol   1097 non-null   float64
#  45  GLD_o Put/Call OI   1097 non-null   float64
#  46  GLD_o Total OI      1097 non-null   float64
#  47  VXX Open            1097 non-null   float64
#  48  VXX High            1097 non-null   float64
#  49  VXX Low             1097 non-null   float64
#  50  VXX Last            1097 non-null   float64
#  51  VXX Change          1097 non-null   float64
#  52  VXX %Chg            1097 non-null   float64
#  53  VXX Volume          1097 non-null   float64
#  54  DXY Open            1097 non-null   float64
#  55  DXY High            1097 non-null   float64
#  56  DXY Low             1097 non-null   float64
#  57  DXY Last            1097 non-null   float64
#  58  DXY Change          1097 non-null   float64
#  59  DXY %Chg            1097 non-null   float64
#  60  DXY Volume          1097 non-null   float64
#  61  CMBO Open           1097 non-null   float64
#  62  CMBO High           1097 non-null   float64
#  63  CMBO Low            1097 non-null   float64
#  64  CMBO Last           1097 non-null   float64
#  65  CMBO Change         1097 non-null   float64
#  66  CMBO %Chg           1097 non-null   float64
#  67  CMBO Volume         1097 non-null   float64
# dtypes: datetime64[ns](1), float64(67)
# memory usage: 582.9 KB

# %%
data["Target"] = data["SPY Last"].shift(-1)

# %%
data.sort_values(by="Date",inplace=True)

# %%
data.dropna(inplace=True)

# %%
df = data.drop(["Date"],axis=1)

# %%
df.head(2)
# Out:
#    SPY Open  SPY High  SPY Low  SPY Last  SPY Change  SPY %Chg   SPY Volume  \
# 0    292.74    293.21   291.32    291.72        0.16      0.05   64694500.0
# 1    291.18    291.24   287.66    289.44       -2.28     -0.78  111545904.0
#
#      SPY RSI  SPY_o Imp Vol  SPY_o 1D IV Chg  ...  DXY %Chg  DXY Volume  \
# 0  54.634025           8.69            -0.45  ...      0.62         0.0
# 1  54.634025          10.07             1.38  ...     -0.33         0.0
#
#    CMBO Open  CMBO High  CMBO Low  CMBO Last  CMBO Change  CMBO %Chg  \
# 0    1980.64    1980.64   1980.64    1980.64         1.37       0.07
# 1    1967.24    1967.24   1967.24    1967.24       -13.40      -0.68
#
#    CMBO Volume  Target
# 0          0.0  289.44
# 1          0.0  287.82
#
# [2 rows x 68 columns]

# %% [markdown]
# # FEATURE SELECTION

# %%
# target datafarem containing target labels
Y = df[["Target"]]

# possible feature space
X = df.drop(Y.columns,axis=1)

# %%
scalerX = MinMaxScaler()
X = scalerX.fit_transform(X)

scalerY = MinMaxScaler()
Y = scalerY.fit_transform(Y)

# %%
Y
# Out:
# array([[0.26099074],
#        [0.25463181],
#        [0.25463181],
#        ...,
#        [0.73677186],
#        [0.72279793],
#        [0.72652693]])

# %%
scalerY.inverse_transform(Y)
# Out:
# array([[289.44],
#        [287.82],
#        [287.82],
#        ...,
#        [410.65],
#        [407.09],
#        [408.04]])

# %%
feature_names = df.drop(["Target"],axis=1).columns.values

# %% [markdown]
# # RFE BASED ON XGB MODEL

# %%
def get_rfe_results(n_features):
    reg = XGBRegressor(colsample_bytree = 0.7, 
                     learning_rate = 0.05, 
                     max_depth= 7, min_child_weight = 4, 
                     n_estimators = 100, nthread = 4, 
                     objective = 'reg:squarederror',
                     subsample = 0.7)

    # create the RFE model
    rfe = RFE(reg,n_features_to_select=n_features)
    rfe.fit(X, Y)
    
    selected_features = [feature for feature, rank in zip(list(feature_names), rfe.ranking_) if rank==1]

    return selected_features

# %%
def get_xgb_results(selected_features):
    features = df[selected_features]
    target = df[["Target"]]
    X_train,X_test,y_train,y_test = train_test_split(features,target,train_size=0.8,shuffle=False)
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    pred_scaler = MinMaxScaler()
    y_train = pred_scaler.fit_transform(y_train)
    y_test = pred_scaler.transform(y_test)
    
    model = XGBRegressor(colsample_bytree = 0.7, 
                     learning_rate = 0.05, 
                     max_depth= 7, min_child_weight = 4, 
                     n_estimators = 100, nthread = 4, 
                     objective = 'reg:squarederror',
                     subsample = 0.7)
    
    model.fit(X_train,y_train)
    preds = model.predict(X_test)
    mae = mean_absolute_error(y_test,preds)
    mse = mean_squared_error(y_test,preds)
    return (mae,mse)

# %%
results = []
for i in range(1,60):
    print("Testing with n_features_to_select = ",i)
    selected_features = get_rfe_results(i)
    mae,mse = get_xgb_results(selected_features)
    print("Mean Absolute Error = {:.4f}".format(mae))
    print("\t---------------")
    results.append({"n_features":i , "mae":mae , "mse":mse})
# Out:
# Testing with n_features_to_select =  1
# Mean Absolute Error = 0.0233
# 	---------------
# Testing with n_features_to_select =  2
# Mean Absolute Error = 0.0220
# 	---------------
# Testing with n_features_to_select =  3
# Mean Absolute Error = 0.0234
# 	---------------
# Testing with n_features_to_select =  4
# Mean Absolute Error = 0.0223
# 	---------------
# Testing with n_features_to_select =  5
# Mean Absolute Error = 0.0245
# 	---------------
# Testing with n_features_to_select =  6
# Mean Absolute Error = 0.0252
# 	---------------
# Testing with n_features_to_select =  7
# Mean Absolute Error = 0.0249
# 	---------------
# Testing with n_features_to_select =  8
# Mean Absolute Error = 0.0255
# 	---------------
# Testing with n_features_to_select =  9
# Mean Absolute Error = 0.0264
# 	---------------
# Testing with n_features_to_select =  10
# Mean Absolute Error = 0.0278
# 	---------------
# Testing with n_features_to_select =  11
# Mean Absolute Error = 0.0287
# 	---------------
# Testing with n_features_to_select =  12
# Mean Absolute Error = 0.0318
# 	---------------
# Testing with n_features_to_select =  13
# Mean Absolute Error = 0.0283
# 	---------------
# Testing with n_features_to_select =  14
# Mean Absolute Error = 0.0306
# 	---------------
# Testing with n_features_to_select =  15
# Mean Absolute Error = 0.0319
# 	---------------
# Testing with n_features_to_select =  16
# Mean Absolute Error = 0.0315
# 	---------------
# Testing with n_features_to_select =  17
# Mean Absolute Error = 0.0307
# 	---------------
# Testing with n_features_to_select =  18
# Mean Absolute Error = 0.0296
# 	---------------
# Testing with n_features_to_select =  19
# Mean Absolute Error = 0.0306
# 	---------------
# Testing with n_features_to_select =  20
# Mean Absolute Error = 0.0330
# 	---------------
# Testing with n_features_to_select =  21
# Mean Absolute Error = 0.0293
# 	---------------
# Testing with n_features_to_select =  22
# Mean Absolute Error = 0.0301
# 	---------------
# Testing with n_features_to_select =  23
# Mean Absolute Error = 0.0366
# 	---------------
# Testing with n_features_to_select =  24
# Mean Absolute Error = 0.0277
# 	---------------
# Testing with n_features_to_select =  25
# Mean Absolute Error = 0.0310
# 	---------------
# Testing with n_features_to_select =  26
# Mean Absolute Error = 0.0287
# 	---------------
# Testing with n_features_to_select =  27
# Mean Absolute Error = 0.0297
# 	---------------
# Testing with n_features_to_select =  28
# Mean Absolute Error = 0.0270
# 	---------------
# Testing with n_features_to_select =  29
# Mean Absolute Error = 0.0333
# 	---------------
# Testing with n_features_to_select =  30
# Mean Absolute Error = 0.0338
# 	---------------
# Testing with n_features_to_select =  31
# Mean Absolute Error = 0.0389
# 	---------------
# Testing with n_features_to_select =  32
# Mean Absolute Error = 0.0350
# 	---------------
# Testing with n_features_to_select =  33
# Mean Absolute Error = 0.0318
# 	---------------
# Testing with n_features_to_select =  34
# Mean Absolute Error = 0.0328
# 	---------------
# Testing with n_features_to_select =  35
# Mean Absolute Error = 0.0326
# 	---------------
# Testing with n_features_to_select =  36
# Mean Absolute Error = 0.0300
# 	---------------
# Testing with n_features_to_select =  37
# Mean Absolute Error = 0.0353
# 	---------------
# Testing with n_features_to_select =  38
# Mean Absolute Error = 0.0350
# 	---------------
# Testing with n_features_to_select =  39
# Mean Absolute Error = 0.0335
# 	---------------
# Testing with n_features_to_select =  40
# Mean Absolute Error = 0.0318
# 	---------------
# Testing with n_features_to_select =  41
# Mean Absolute Error = 0.0315
# 	---------------
# Testing with n_features_to_select =  42
# Mean Absolute Error = 0.0371
# 	---------------
# Testing with n_features_to_select =  43
# Mean Absolute Error = 0.0349
# 	---------------
# Testing with n_features_to_select =  44
# Mean Absolute Error = 0.0310
# 	---------------
# Testing with n_features_to_select =  45
# Mean Absolute Error = 0.0355
# 	---------------
# Testing with n_features_to_select =  46
# Mean Absolute Error = 0.0299
# 	---------------
# Testing with n_features_to_select =  47
# Mean Absolute Error = 0.0384
# 	---------------
# Testing with n_features_to_select =  48
# Mean Absolute Error = 0.0323
# 	---------------
# Testing with n_features_to_select =  49
# Mean Absolute Error = 0.0307
# 	---------------
# Testing with n_features_to_select =  50
# Mean Absolute Error = 0.0359
# 	---------------
# Testing with n_features_to_select =  51
# Mean Absolute Error = 0.0266
# 	---------------
# Testing with n_features_to_select =  52
# Mean Absolute Error = 0.0302
# 	---------------
# Testing with n_features_to_select =  53
# Mean Absolute Error = 0.0318
# 	---------------
# Testing with n_features_to_select =  54
# Mean Absolute Error = 0.0322
# 	---------------
# Testing with n_features_to_select =  55
# Mean Absolute Error = 0.0353
# 	---------------
# Testing with n_features_to_select =  56
# Mean Absolute Error = 0.0306
# 	---------------
# Testing with n_features_to_select =  57
# Mean Absolute Error = 0.0367
# 	---------------
# Testing with n_features_to_select =  58
# Mean Absolute Error = 0.0328
# 	---------------
# Testing with n_features_to_select =  59
# Mean Absolute Error = 0.0333
# 	---------------

# %%
result_data = pd.DataFrame(results)

# %%
plt.figure(figsize=(20,8))
plt.plot(result_data.mse,label = "Meas Squared Error")
plt.xlabel("Number of features selected")
plt.ylabel("Error")
plt.title("MAE Analysis")
plt.legend()

# %%
plt.figure(figsize=(20,8))
plt.plot(result_data.mae,label = "Meas Absolute Error")
# plt.plot(result_data.mse,label = "Meas Squared Error")
plt.xlabel("Number of features selected")
plt.ylabel("Error")
plt.title("MAE Analysis")
plt.legend()

# %%
# result_data.to_csv("n_features_comparison.csv")

# %%
features = df[selected_features]
target = df[["Target"]]

# %% [markdown]
# # PRE-PROCESSING

# %%
X_train,X_test,y_train,y_test = train_test_split(features,target,train_size=0.8,shuffle=False)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

pred_scaler = MinMaxScaler()
y_train = pred_scaler.fit_transform(y_train)
y_test = pred_scaler.transform(y_test)

# %%
df[["Target"]].iloc[0][0] , pred_scaler.inverse_transform(y_train)[0][0]
# Out:
# (289.44, 289.44)

# %% [markdown]
# # PREDICTION

# %%
model = XGBRegressor(colsample_bytree = 0.7, 
                     learning_rate = 0.05, 
                     max_depth= 7, min_child_weight = 4, 
                     n_estimators = 100, nthread = 4, 
                     objective = 'reg:linear',
                     subsample = 0.7)

# %%
model.fit(X_train,y_train)
# Out:
# [00:56:22] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=4, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, nthread=4, num_parallel_tree=None,
#              objective='reg:linear', ...)

# %%
preds = model.predict(X_test)

# %% [markdown]
# ## EVALUATION

# %%
print("Mean absolute Error = {:.4f}".format(mean_absolute_error(y_test,preds)))
print("Mean squared Error = {:.4f}".format(mean_squared_error(y_test,preds)))
# Out:
# Mean absolute Error = 0.0282
# Mean squared Error = 0.0013

# %%
INPUT_FEATURES_VALUES = features #feature value from actual data frame
ACTUAL_TARGET_VALUES = target.values #target column from actual data
scaled_input = scaler.transform(INPUT_FEATURES_VALUES) #scaling features to feed model to get results

# FETTING MODEL'S PREDICTION OVER FEATURES FROM DATA
PREDICTED_MODEL_OUTPUT = model.predict(scaled_input)

# %%
PREDICTED_MODEL_OUTPUT = pred_scaler.inverse_transform(PREDICTED_MODEL_OUTPUT.reshape(-1,1))

# %%
resultant_dataframe = pd.DataFrame({'ACTUAL_TARGET_VALUES':ACTUAL_TARGET_VALUES.ravel(), 
                                    'PREDICTED_MODEL_OUTPUT':PREDICTED_MODEL_OUTPUT.ravel()})

# %%
resultant_dataframe.insert(1, "residuals",
                           resultant_dataframe["PREDICTED_MODEL_OUTPUT"] - resultant_dataframe["ACTUAL_TARGET_VALUES"],
                           True)

# %%
df_sub = ["#2BC97A" if x > 0 else "#C92B2B" for x in resultant_dataframe["residuals"].dropna()]

# %%
resultant_dataframe.index = data.Date

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y = resultant_dataframe["ACTUAL_TARGET_VALUES"] , x = resultant_dataframe.index,
                      name = "ACTUAL" , mode="lines"))
fig.add_trace(go.Scatter(y = resultant_dataframe["PREDICTED_MODEL_OUTPUT"] , x = resultant_dataframe.index,
                     name = "PREDICTED",mode = "lines"))
fig.add_trace(
    go.Bar(y = resultant_dataframe["residuals"].dropna() ,  x = resultant_dataframe.index,
           marker = {'color' : df_sub}, name = "Difference")
)
fig.update_layout(
        xaxis = dict(rangeslider=dict(
            visible=True
        ),
        type="date"),
        hovermode="x unified" , width = 1000,
        legend_title= "TRACES",
        yaxis_title= "VALUE OF TARGET LAST" ,xaxis_title="TIME",
        hoverlabel = dict(
            bgcolor="white",
            font_size=16,
            font_family="Rockwell"
        )
    )
fig.show()
# Out:
# /home/huda/.local/lib/python3.8/site-packages/plotly/io/_renderers.py:396: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.
# <div>                            <div id="d1018d04-3dbb-4dbf-b5e5-1c652b77155a" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1018d04-3dbb-4dbf-b5e5-1c652b77155a")) {                    Plotly.newPlot(                        "d1018d04-3dbb-4dbf-b5e5-1c652b77155a",                        [{"mode":"lines","name":"ACTUAL","x":["2018-10-03T00:00:00","2018-10-04T00:00:00","2018-10-05T00:00:00","2018-10-08T00:00:00","2018-10-09T00:00:00","2018-10-10T00:00:00","2018-10-11T00:00:00","2018-10-12T00:00:00","2018-10-15T00:00:00","2018-10-16T00:00:00","2018-10-17T00:00:00","2018-10-18T00:00:00","2018-10-19T00:00:00","2018-10-22T00:00:00","2018-10-23T00:00:00","2018-10-24T00:00:00","2018-10-25T00:00:00","2018-10-26T00:00:00","2018-10-29T00:00:00","2018-10-30T00:00:00","2018-10-31T00:00:00","2018-11-01T00:00:00","2018-11-02T00:00:00","2018-11-05T00:00:00","2018-11-06T00:00:00","2018-11-07T00:00:00","2018-11-08T00:00:00","2018-11-09T00:00:00","2018-11-12T00:00:00","2018-11-13T00:00:00","2018-11-14T00:00:00","2018-11-15T00:00:00","2018-11-16T00:00:00","2018-11-19T00:00:00","2018-11-20T00:00:00","2018-11-21T00:00:00","2018-11-23T00:00:00","2018-11-26T00:00:00","2018-11-27T00:00:00","2018-11-28T00:00:00","2018-11-29T00:00:00","2018-11-30T00:00:00","2018-12-03T00:00:00","2018-12-04T00:00:00","2018-12-06T00:00:00","2018-12-07T00:00:00","2018-12-10T00:00:00","2018-12-11T00:00:00","2018-12-12T00:00:00","2018-12-13T00:00:00","2018-12-14T00:00:00","2018-12-17T00:00:00","2018-12-18T00:00:00","2018-12-19T00:00:00","2018-12-20T00:00:00","2018-12-21T00:00:00","2018-12-24T00:00:00","2018-12-26T00:00:00","2018-12-27T00:00:00","2018-12-28T00:00:00","2018-12-31T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-01T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00 ...

# %% [markdown]
# # HUNT FOR BEST PARAMETERS FOR THE REGRESSOR

# %%
xgb = XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500,100,50]}

xgb_grid = GridSearchCV(xgb,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# %%
xgb_grid.fit(MinMaxScaler().fit_transform(features),MinMaxScaler().fit_transform(target))

# %%
print(xgb_grid.best_params_)

# %%
print(abs(xgb_grid.best_score_))

# %% [markdown]
# #

# %% [markdown]
# # Data from 1993 onwards with only 4 features

# %% [markdown]
# # Data with 4 features

# %%
data = etl(pd.read_csv("SPY.csv"))

# %%
data.head(2)
# Out:
#         Date      Open      High       Low    Close  Adj Close   Volume
# 0 1993-01-29  43.96875  43.96875  43.75000  43.9375  25.218218  1003200
# 1 1993-02-01  43.96875  44.25000  43.96875  44.2500  25.397591   480500

# %%
sents = pd.read_csv("sentiments.csv",skiprows=6)
sents.columns = ["Date","Sentiment_Index"]
sents.dropna(inplace=True)
sents.Date = pd.to_datetime(sents.Date)

# %%
sents.head(2)
# Out:
#         Date  Sentiment_Index
# 0 2018-02-06            100.0
# 1 2018-02-07             99.5

# %%
data = data.merge(sents,on="Date")

# %%
data.sort_values(by="Date",inplace=True)
data["Target"] = data["Close"].shift(-1)
data.dropna(inplace=True)
df = data.drop(["Date"],axis=1)

# %%
df.head(3)
# Out:
#          Open        High         Low       Close   Adj Close     Volume  \
# 0  259.940002  269.700012  258.700012  269.130005  247.097229  355026800
# 1  268.500000  272.359985  267.579987  267.670013  245.756729  167376100
# 2  268.010010  268.170013  257.589996  257.630005  236.538635  246449500
#
#    Sentiment_Index      Target
# 0           100.00  267.670013
# 1            99.50  257.630005
# 2            95.76  261.500000

# %%
feats = ["Open","High","Low","Close","Sentiment_Index"]

# %%
# df# target datafarem containing target labels
Y = df[["Target"]]

# possible feature space
X = df[feats]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42,shuffle=True)

# Normalize the data using the standard scaler
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

pred_sc = MinMaxScaler()
y_train = pred_sc.fit_transform(y_train)
y_test = pred_sc.transform(y_test)

# %%
xgb = XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:squarederror'],
              'learning_rate': [.03, 0.05, .07,0.01], #so called `eta` value
              'max_depth': [5, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500,100,50,40]}

xgb_grid = GridSearchCV(xgb,
                        parameters,
                        cv = 2,
                        n_jobs = -2,
                        verbose=True)

# %%
xgb_grid.fit(MinMaxScaler().fit_transform(X),MinMaxScaler().fit_transform(Y))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
xgb = XGBRegressor(colsample_bytree = 0.7, 
                     learning_rate = 0.05, 
                     max_depth= 7, min_child_weight = 4, 
                     n_estimators = 100, nthread = 4, 
                     objective = 'reg:squarederror',
                     subsample = 0.7)

evalset = [(X_train, y_train), (X_test,y_test)]
# fit the model
xgb.fit(X_train, y_train, eval_metric='mae', eval_set=evalset)

# xgb.fit(X_train,y_train.ravel())
# yhat = xgb.predict(X_test)
# Out:
# [0]	validation_0-mae:0.24114	validation_1-mae:0.25462
# [1]	validation_0-mae:0.22934	validation_1-mae:0.24231
# [2]	validation_0-mae:0.21809	validation_1-mae:0.23066
# [3]	validation_0-mae:0.20737	validation_1-mae:0.21950
# /home/huda/.local/lib/python3.8/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-mae:0.19719	validation_1-mae:0.20900
# [5]	validation_0-mae:0.18750	validation_1-mae:0.19898
# [6]	validation_0-mae:0.17827	validation_1-mae:0.18938
# [7]	validation_0-mae:0.16951	validation_1-mae:0.18029
# [8]	validation_0-mae:0.16122	validation_1-mae:0.17174
# [9]	validation_0-mae:0.15331	validation_1-mae:0.16347
# [10]	validation_0-mae:0.14575	validation_1-mae:0.15571
# [11]	validation_0-mae:0.13860	validation_1-mae:0.14828
# [12]	validation_0-mae:0.13178	validation_1-mae:0.14118
# [13]	validation_0-mae:0.12530	validation_1-mae:0.13442
# [14]	validation_0-mae:0.11915	validation_1-mae:0.12807
# [15]	validation_0-mae:0.11335	validation_1-mae:0.12208
# [16]	validation_0-mae:0.10782	validation_1-mae:0.11635
# [17]	validation_0-mae:0.10256	validation_1-mae:0.11094
# [18]	validation_0-mae:0.09756	validation_1-mae:0.10572
# [19]	validation_0-mae:0.09277	validation_1-mae:0.10074
# [20]	validation_0-mae:0.08828	validation_1-mae:0.09609
# [21]	validation_0-mae:0.08399	validation_1-mae:0.09167
# [22]	validation_0-mae:0.07990	validation_1-mae:0.08745
# [23]	validation_0-mae:0.07604	validation_1-mae:0.08335
# [24]	validation_0-mae:0.07240	validation_1-mae:0.07955
# [25]	validation_0-mae:0.06890	validation_1-mae:0.07597
# [26]	validation_0-mae:0.06558	validation_1-mae:0.07254
# [27]	validation_0-mae:0.06242	validation_1-mae:0.06927
# [28]	validation_0-mae:0.05943	validation_1-mae:0.06616
# [29]	validation_0-mae:0.05659	validation_1-mae:0.06319
# [30]	validation_0-mae:0.05393	validation_1-mae:0.06043
# [31]	validation_0-mae:0.05137	validation_1-mae:0.05777
# [32]	validation_0-mae:0.04890	validation_1-mae:0.05522
# [33]	validation_0-mae:0.04659	validation_1-mae:0.05286
# [34]	validation_0-mae:0.04442	validation_1-mae:0.05064
# [35]	validation_0-mae:0.04233	validation_1-mae:0.04850
# [36]	validation_0-mae:0.04039	validation_1-mae:0.04646
# [37]	validation_0-mae:0.03851	validation_1-mae:0.04454
# [38]	validation_0-mae:0.03675	validation_1-mae:0.04269
# [39]	validation_0-mae:0.03505	validation_1-mae:0.04095
# [40]	validation_0-mae:0.03343	validation_1-mae:0.03931
# [41]	validation_0-mae:0.03194	validation_1-mae:0.03774
# [42]	validation_0-mae:0.03054	validation_1-mae:0.03631
# [43]	validation_0-mae:0.02923	validation_1-mae:0.03497
# [44]	validation_0-mae:0.02795	validation_1-mae:0.03364
# [45]	validation_0-mae:0.02672	validation_1-mae:0.03241
# [46]	validation_0-mae:0.02560	validation_1-mae:0.03129
# [47]	validation_0-mae:0.02453	validation_1-mae:0.03025
# [48]	validation_0-mae:0.02351	validation_1-mae:0.02925
# [49]	validation_0-mae:0.02255	validation_1-mae:0.02826
# [50]	validation_0-mae:0.02163	validation_1-mae:0.02735
# [51]	validation_0-mae:0.02078	validation_1-mae:0.02654
# [52]	validation_0-mae:0.01997	validation_1-mae:0.02579
# [53]	validation_0-mae:0.01920	validation_1-mae:0.02505
# [54]	validation_0-mae:0.01847	validation_1-mae:0.02438
# [55]	validation_0-mae:0.01782	validation_1-mae:0.02374
# [56]	validation_0-mae:0.01719	validation_1-mae:0.02317
# [57]	validation_0-mae:0.01660	validation_1-mae:0.02262
# [58]	validation_0-mae:0.01604	validation_1-mae:0.02212
# [59]	validation_0-mae:0.01552	validation_1-mae:0.02164
# [60]	validation_0-mae:0.01504	validation_1-mae:0.02121
# [61]	validation_0-mae:0.01460	validation_1-mae:0.02078
# [62]	validation_0-mae:0.01419	validation_1-mae:0.02035
# [63]	validation_0-mae:0.01378	validation_1-mae:0.01999
# [64]	validation_0-mae:0.01339	validation_1-mae:0.01962
# [65]	validation_0-mae:0.01303	validation_1-mae:0.01931
# [66]	validation_0-mae:0.01270	validation_1-mae:0.01903
# [67]	validation_0-mae:0.01237	validation_1-mae:0.01869
# [68]	validation_0-mae:0.01206	validation_1-mae:0.01843
# [69]	validation_0-mae:0.01178	validation_1-mae:0.01817
# [70]	validation_0-mae:0.01151	validation_1-mae:0.01797
# [71]	validation_0-mae:0.01127	validation_1-mae:0.01776
# [72]	validation_0-mae:0.01103	validation_1-mae:0.01755
# [73]	validation_0-mae:0.01084	validation_1-mae:0.01740
# [74]	validation_0-mae:0.01065	validation_1-mae:0.01723
# [75]	validation_0-mae:0.01047	validation_1-mae:0.01708
# [76]	validation_0-mae:0.01030	validation_1-mae:0.01694
# [77]	validation_0-mae:0.01016	validation_1-mae:0.01681
# [78]	validation_0-mae:0.01002	validation_1-mae:0.01671
# [79]	validation_0-mae:0.00989	validation_1-mae:0.01657
# [80]	validation_0-mae:0.00976	validation_1-mae:0.01649
# [81]	validation_0-mae:0.00963	validation_1-mae:0.01640
# [82]	validation_0-mae:0.00953	validation_1-mae:0.01629
# [83]	validation_0-mae:0.00943	validation_1-mae:0.01620
# [84]	validation_0-mae:0.00934	validation_1-mae:0.01610
# [85]	validation_0-mae:0.00925	validation_1-mae:0.01601
# [86]	validation_0-mae:0.00916	validation_1-mae:0.01598
# [87]	validation_0-mae:0.00907	validation_1-mae:0.01591
# [88]	validation_0-mae:0.00899	validation_1-mae:0.01581
# [89]	validation_0-mae:0.00892	validation_1-mae:0.01576
# [90]	validation_0-mae:0.00884	validation_1-mae:0.01568
# [91]	validation_0-mae:0.00878	validation_1-mae:0.01563
# [92]	validation_0-mae:0.00873	validation_1-mae:0.01557
# [93]	validation_0-mae:0.00869	validation_1-mae:0.01552
# [94]	validation_0-mae:0.00862	validation_1-mae:0.01546
# [95]	validation_0-mae:0.00858	validation_1-mae:0.01544
# [96]	validation_0-mae:0.00853	validation_1-mae:0.01540
# [97]	validation_0-mae:0.00849	validation_1-mae:0.01538
# [98]	validation_0-mae:0.00844	validation_1-mae:0.01536
# [99]	validation_0-mae:0.00840	validation_1-mae:0.01532
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=4, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, nthread=4, num_parallel_tree=None,
#              predictor=None, ...)

# %%
results = xgb.evals_result()
# plot learning curves
plt.plot(results['validation_0']['mae'], label='train')
plt.plot(results['validation_1']['mae'], label='test')
# show the legend
plt.legend()
# show the plot
# pyplot.show()

# %%
yhat = xgb.predict(X_test)

# %%
mean_absolute_error(y_test,yhat)
# Out:
# 0.015320004279613221

# %%
mean_absolute_error(pred_sc.inverse_transform(y_test),pred_sc.inverse_transform(yhat.reshape(-1,1)))
# Out:
# 3.641717789935253

# %%
a , b = get_comparison_plot(data,feats,pred_sc.transform(Y),xgb,sc,pred_sc)

# %%
b
# Out:
# /home/huda/.local/lib/python3.8/site-packages/plotly/io/_renderers.py:396: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.

# %%
new_data = pd.read_csv("data.csv")
new_data.Date = pd.to_datetime(new_data.Date)

# %%
get_predictions(new_data,
                selected_features = ["Open","High","Low","Close"],
                models = [xgb],
                scalers = [sc],
                pred_scalers = [pred_sc])

# %%
feats = ["High","Low","Sentiment_Index"]

# %%
# target datafarem containing target labels
Y = df[["Target"]]

# possible feature space
X = df[feats]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Normalize the data using the standard scaler
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

pred_sc = MinMaxScaler()
y_train = pred_sc.fit_transform(y_train)
y_test = pred_sc.transform(y_test)

# %%
# Build the neural network model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
# Compile the model
model.compile(loss='mean_absolute_error', optimizer=Adam())

# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_split=0.1,batch_size=32, verbose=2)

# %%
plt.plot(model.history.history["loss"],label="Training Loss")
plt.plot(model.history.history["val_loss"],label="Validation Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")

# %%
# Evaluate the model on the test set
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score)

# %%
model.evaluate(sc.transform(X), pred_sc.transform(Y), verbose=0)

# %%
preds = model.predict(sc.transform(X))
yhat = pred_sc.inverse_transform(preds)
mean_absolute_error(Y,yhat)

# %%
book = {"Actual":Y.values.ravel(),"Predicted":yhat.ravel()}
comp = pd.DataFrame.from_dict(book)
comp["Difference"] = comp.Actual - comp.Predicted

# %%
comp

# %%
def get_predictions(data,selected_features,models,scalers,pred_scalers):
    predictions = {}
    for sf,m,s,p_s in zip(selected_features,models,scalers,pred_scalers):
        d1 = data[sf]
        in_data = s.transform(d1)
        out_data = m.predict(in_data)
        out_data = p_s.inverse_transform([out_data])
        out_data = out_data.ravel()[0]
        predictions[f"{len(sf)} Features Model"] = [out_data]
    
    preds = pd.DataFrame.from_dict(predictions)
    data.Date = pd.to_datetime(data.Date)
    today = data.Date[0].date()
    tom = today + datetime.timedelta(days= 7-today.weekday() if today.weekday()>3 else 1)
    preds.index = [tom]
    return preds

# %%
def get_comparison_plot(data,features,target,model,scaler,pred_scaler):
    INPUT_FEATURES_VALUES = data[features] #feature value from actual data frame
    ACTUAL_TARGET_VALUES = pred_scaler.inverse_transform(target) #target column from actual data
    scaled_input = scaler.transform(INPUT_FEATURES_VALUES) #scaling features to feed model to get results

    # FETTING MODEL'S PREDICTION OVER FEATURES FROM DATA
    PREDICTED_MODEL_OUTPUT = model.predict(scaled_input)
    
    PREDICTED_MODEL_OUTPUT = pred_scaler.inverse_transform(PREDICTED_MODEL_OUTPUT.reshape(-1,1))

    resultant_dataframe = pd.DataFrame({'ACTUAL_TARGET_VALUES':ACTUAL_TARGET_VALUES.ravel(), 
                                        'PREDICTED_MODEL_OUTPUT':PREDICTED_MODEL_OUTPUT.ravel()})

    resultant_dataframe.insert(1, "residuals",
                               resultant_dataframe["PREDICTED_MODEL_OUTPUT"] - resultant_dataframe["ACTUAL_TARGET_VALUES"],
                               True)
    df_sub = ["#2BC97A" if x > 0 else "#C92B2B" for x in resultant_dataframe["residuals"].dropna()]

    resultant_dataframe.index = data.Date

    fig = go.Figure()
    fig.add_trace(go.Scatter(y = resultant_dataframe["ACTUAL_TARGET_VALUES"] , x = resultant_dataframe.index,
                          name = "ACTUAL" , mode="lines"))
    fig.add_trace(go.Scatter(y = resultant_dataframe["PREDICTED_MODEL_OUTPUT"] , x = resultant_dataframe.index,
                         name = "PREDICTED",mode = "lines"))
    fig.add_trace(
        go.Bar(y = resultant_dataframe["residuals"].dropna() ,  x = resultant_dataframe.index,
               marker = {'color' : df_sub}, name = "Difference")
    )
    fig.update_layout(
            xaxis = dict(rangeslider=dict(
                visible=True
            ),
            type="date"),
            hovermode="x unified" , width = 1000,
            legend_title= "TRACES",
            yaxis_title= "VALUE OF TARGET LAST" ,xaxis_title="TIME",
            hoverlabel = dict(
                bgcolor="white",
                font_size=16,
                font_family="Rockwell"
            )
        )
    return resultant_dataframe,fig
